# %%
import requests
from PIL import Image

# %%
subscription_key='84b059f0bedd4a9fac76fc104fad52c7'

# %%
assert subscription_key

# %%
face_api_url= 'https://20210117.cognitiveservices.azure.com/face/v1.0/detect'

# %%
img=Image.open('sample01.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x413 at 0x24A823FB430>

# %%
with open('sample01.jpg','rb')as f:
    binary_img=f.read()

# %%
# binary_img

# %%
headers={'Content-Type':'application/octet-stream',
        'Ocp-Apim-Subscription-Key':subscription_key}

params={'returnFaceId':'true',
        'returnFaceAttributes':'age,gender,headPose,smile,facialHair,glasses,emotion,hair,makeup,occlusion'
}

res=requests.post(face_api_url,params=params,headers=headers,data=binary_img)

# %%
result=res.json()
result
# Out:
# [{'faceId': '425df7a3-e9ec-406c-8e55-8f3f91a1fe54',
#   'faceRectangle': {'top': 144, 'left': 373, 'width': 47, 'height': 47},
#   'faceAttributes': {'smile': 0.683,
#    'headPose': {'pitch': 20.9, 'roll': -0.9, 'yaw': -0.4},
#    'gender': 'male',
#    'age': 30.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.001,
#     'disgust': 0.001,
#     'fear': 0.0,
#     'happiness': 0.683,
#     'neutral': 0.237,
#     'sadness': 0.078,
#     'surprise': 0.0},
#    'makeup': {'eyeMakeup': False, 'lipMakeup': False},
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.02,
#     'invisible': False,
#     'hairColor': [{'color': 'black', 'confidence': 0.99},
#      {'color': 'brown', 'confidence': 0.92},
#      {'color': 'other', 'confidence': 0.27},
#      {'color': 'gray', 'confidence': 0.13},
#      {'color': 'blond', 'confidence': 0.11},
#      {'color': 'red', 'confidence': 0.06},
#      {'color': 'white', 'confidence': 0.0}]}}},
#  {'faceId': 'e5f4132e-12b8-446b-92d5-1aa96fe8058c',
#   'faceRectangle': {'top': 150, 'left': 272, 'width': 45, 'height': 45},
#   'faceAttributes': {'smile': 1.0,
#    'headPose': {'pitch': 11.7, 'roll': 2.3, 'yaw': 11.2},
#    'gender': 'female',
#    'age': 28.0,
#    'facialHair': {'moustache': 0.0, 'beard': 0.0, 'sideburns': 0.0},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 1.0,
#     'neutral': 0.0,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'makeup': {'eyeMakeup': True, 'lipMakeup': False},
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.01,
#     'invisible': False,
#     'hairColor': [{'color': 'brown', 'confidence': 1.0},
#      {'color': 'blond', 'confidence': 0.72},
#      {'color': 'red', 'confidence': 0.52},
#      {'color': 'black', 'confidence': 0.35},
#      {'color': 'other', 'confidence': 0.05},
#      {'color': 'gray', 'confidence': 0.04},
#      {'color': 'white', 'confidence': 0.0}]}}},
#  {'faceId': '4af9b081-719f-4e96-addb-d0cfca9cb6c1',
#   'faceRectangle': {'top': 142, 'left': 134, 'width': 43, 'height': 43},
#   'faceAttributes': {'smile': 1.0,
#    'headPose': {'pitch': 6.0, 'roll': 8.6, 'yaw': 23.1},
#    'gender': 'male',
#    'age': 30.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 1.0,
#     'neutral': 0.0,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'makeup': {'eyeMakeup': True, 'lipMakeup': False},
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.07,
#     'invisible': False,
#     'hairColor': [{'color': 'black', 'confidence': 1.0},
#      {'color': 'brown', 'confidence': 0.57},
#      {'color': 'other', 'confidence': 0.53},
#      {'color': 'gray', 'confidence': 0.47},
#      {'color': 'blond', 'confidence': 0.04},
#      {'color': 'red', 'confidence': 0.01},
#      {'color': 'white', 'confidence': 0.0}]}}}]

# %%
rect=result[0]['faceRectangle']
rect
# Out:
# {'top': 144, 'left': 373, 'width': 47, 'height': 47}

# %%
from PIL import ImageDraw

# %%
draw=ImageDraw.Draw(img)

# %%
draw.rectangle([(rect['left'],rect['top']),(rect['left']+rect['width'],rect['top']+rect['height'])],
               fill=None,outline='green',width=5)

# %%
draw=ImageDraw.Draw(img)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x413 at 0x24A823FB430>
